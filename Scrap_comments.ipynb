# %%
# 타임스탬프 제거
# 댓글이 다 안끌려옴

# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
# Setting option to running selenium to Background
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')

# %%
# Youtube link
url = "https://www.youtube.com/watch?v=quaCPddGc7k"

# %%
#driver = webdriver.Chrome("/Users/power/aa/chromedriver")
driver = webdriver.Chrome("/Users/taego/PycharmProjects/Caps/sentiment_analysis/chromedriver")
# Out:
# C:\Users\taego\AppData\Local\Temp/ipykernel_8372/2024089789.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/Users/taego/PycharmProjects/Caps/chromedriver")

# %%
# Move to url
driver.get(url)
time.sleep(3)

# %%
# Scroll down
body = driver.find_element_by_tag_name('body')
last_page_height = driver.execute_script("return document.documentElement.scrollHeight")

while True: 
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(3)
    new_page_height = driver.execute_script("return document.documentElement.scrollHeight") 
    
    if new_page_height == last_page_height: 
        break
    last_page_height = new_page_height
# Out:
# C:\Users\taego\AppData\Local\Temp/ipykernel_8372/1551062795.py:2: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   body = driver.find_element_by_tag_name('body')

# %%
# Save html code to comments_html
comments_html = driver.page_source

# %%
# Quit selenium
driver.quit()

# %%
comments_soup = BeautifulSoup(comments_html, 'lxml')

# %%
ids_html = comments_soup.select('div#header-author > h3 > #author-text > span')
comments_html = comments_soup.select('yt-formatted-string#content-text')

comments_len = len(comments_html)
ids_len = len(ids_html)

comments_len
# Out:
# 1160

# %%
comments_html
# Out:
# [<yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=ctmEaiKokOs&amp;t=196s" spellcheck="false">3:16</a><span class="style-scope yt-formatted-string" dir="auto"> 완벽한 침투에 이어 오프사이드 안 걸리게 최종 위치 선정까지.. 쏘니는 그냥 미쳤다</span></yt-formatted-string>,
#  <yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">이번 경기 골말고 드리블 보시면 역대급입니다.. 진짜 군더더기없이 깔끔한데 리버풀 상대로 진짜 완벽했음.</yt-formatted-string>,
#  <yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/watch?v=ctmEaiKokOs&amp;t=32s" spellcheck="false">0:32</a><span class="style-scope yt-formatted-string" dir="auto"> 케인 공 받기전 쏘니 체크</span><span class="style-scope yt-formatted-string" dir="auto">
# ...

# %%
ids_html
# Out:
# [<span class="style-scope ytd-comment-renderer">
#                동심파괴
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                윤서이
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                jw
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                이지완
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                다잘될거야
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                LIMA
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                루시퍼
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                1분홈즈
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                Df Kr
#              </span>,
#  <span class="style-scope ytd-comment-renderer">
#                뭐재밌는거없을까
#              </span>,
# ...

# %%
aa = comments_html[0].select_one('yt-formatted-string#content-text')
print(aa)
# Out:
# None

# %%
# Empty listsel
Ids = []
Comments = []

# %%
for i in range(comments_len):
    Ids.append(list(ids_html[i].select_one('style-scope ytd-comment-renderer').
                   stripped_strings)[0])
    comments.append(list(comments_html[i].select_one('')))

# %%
for i in range(ids_len):
    temp_id = ids_html[i].text
    temp_id = temp_id.replace('\n', '')
    temp_id = temp_id.replace('\t', '')
    temp_id = temp_id.replace('    ', '')
    Ids.append(temp_id)

    temp_comment = comments_html[i].text
    temp_comment = temp_comment.replace('\n', '')
    temp_comment = temp_comment.replace('\t', '')
    temp_comment = temp_comment.replace('    ', '')
    Comments.append(temp_comment)

# %%
youtube_df = pd.DataFrame([Ids,
                            Comments,],
                            index = ['ID', 'Comment']).T
youtube_df
# Out:
#            ID                                            Comment
# 0       스퀴프BS  이 채널이 좋은게 지금 뻔뻔하게 활동하는 유튜버들이 예전에 했던 이상한 짓들을 다시...
# 1          아율  악인전님 언제나 유익하고 흥미로운 영상 올려주셔서 감사합니다!이렇게 보면 정말 우리...
# 2        오호포로  이 컨셉은 정말 어느순간 실수한방에 훅갈수도 있는데부디 최대한 중립적이고 냉정하게 ...
# 3         유현타  예전엔 새로운 맛집 찾기 좋고 편집도 깔끔해서 즐겨봤는데 영향력이 커진 후론 겸손함...
# 4         맹화이  간장게장 사장님 한동안 음식 재사용집이라고 오는 장난전화 때문에 심적으로 엄청 힘들...
# ...       ...                                                ...
# 2255      탱땡볼                                            와나오산사는데
# 2256      ?읭?                              주제에뭐라고 남의인생 나락으로끌어내리냐
# 2257      이정후                              댓글 싸악 닫았네 ㅋㅋㅋㅋ꼬시다 꼬시야
# 2258       끼리                                    하얀트리 목소리가 ㅈ같음 ㅋ
# 2259    국밥부장관                                        목소리 ㄹㅇ극혐 ㅋㅋ
#
# [2260 rows x 2 columns]

# %%
# save to excel
youtube_df.to_excel('77.xlsx')
